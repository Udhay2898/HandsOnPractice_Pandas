# %% [markdown]
# <a href="https://colab.research.google.com/github/Udhay2898/Pandas_Tutorial_Code/blob/master/TATA_Stocks_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tata = pd.read_csv('/content/drive/MyDrive/Data Sets/TATA Stacks/TATAMOTORS_BSE_01Oct20-01Oct21.csv')
tata.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-10-01  135.699997  136.500000  132.600006  133.500000  133.500000
# 1  2020-10-05  137.000000  137.500000  132.050003  133.899994  133.899994
# 2  2020-10-06  137.800003  145.699997  135.899994  144.850006  144.850006
# 3  2020-10-07  144.100006  144.500000  139.800003  141.000000  141.000000
# 4  2020-10-08  142.800003  143.350006  139.649994  140.899994  140.899994
#
#        Volume
# 0   1674311.0
# 1   2800303.0
# 2  10190922.0
# 3   4032654.0
# 4   2491175.0

# %%
tata.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  247.000000  247.000000  247.000000  247.000000  247.000000
# mean   268.256882  272.963360  263.290485  267.972268  267.972268
# std     70.885356   71.814761   69.668101   70.595849   70.595849
# min    128.000000  130.000000  126.000000  127.000000  127.000000
# 25%    186.849998  188.675003  183.925003  186.375000  186.375000
# 50%    299.299988  303.500000  293.649994  298.799988  298.799988
# 75%    317.050003  324.125000  312.125000  318.025009  318.025009
# max    356.500000  360.649994  351.200012  356.000000  356.000000
#
#              Volume
# count  2.470000e+02
# mean   3.918008e+06
# std    3.488840e+06
# min    4.781380e+05
# 25%    1.715184e+06
# 50%    2.891967e+06
# 75%    4.656536e+06
# max    2.285476e+07

# %%
tata.isnull().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
tata.shape
# Out:
# (248, 7)

# %%
tata['Time'] = np.arange(len(tata.index))
fig, ax = plt.subplots()
ax.plot('Time', 'Volume', data=tata, color='0.75')
ax = sns.regplot(x='Time', y='Volume', data=tata, ci=None, scatter_kws=dict(color='0.25'))
ax.set_title('Time Plot of Volume');
