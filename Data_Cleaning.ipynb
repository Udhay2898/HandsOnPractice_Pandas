# %% [markdown]
# <a href="https://colab.research.google.com/github/Udhay2898/Pandas_Tutorial_Code/blob/master/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Read CSV File from Drive**

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Sets/Highest Average.csv')
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
#
#       SR  100  50  0    4s  6s
# 0  58.60   29  13  7  626+   6
# 1  91.76    4   7  1   141  23
# 2  55.68    5   4  2   186   5
# 3  54.48    7  11  1  246+  11
# 4  56.00   10   5  2  104+   1

# %% [markdown]
# **Check Null Values**

# %%
df.isnull().any()
# Out:
# Player    False
# Span      False
# Mat       False
# Inns      False
# NO        False
# Runs      False
# HS        False
# Ave       False
# BF        False
# SR        False
# 100       False
# 50        False
# 0         False
# 4s        False
# 6s        False
# dtype: bool

# %% [markdown]
# **Check The Duplicates**

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %% [markdown]
# **Find the Duplicates**

# %%
df[df['Player'].duplicated()==1]
# Out:
#                 Player       Span  Mat  Inns  NO   Runs    HS    Ave      BF  \
# 5      RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97   1707+
# 25  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437+
# 53       V Kohli (IND)  2011-2024  113   191  11   8848  254*  49.15   15924
#
#        SR  100  50   0     4s  6s
# 5   54.48    7  11   1   246+  11
# 25  54.04   51  68  14  2058+  69
# 53  55.56   29  30  14    991  26

# %% [markdown]
# **List the Duplicates**

# %%
df[df['Player'].isin(['RG Pollock (SA)','SR Tendulkar (IND)','V Kohli (IND)'])]
# Out:
#                 Player       Span  Mat  Inns  NO   Runs    HS    Ave      BF  \
# 3      RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97   1707+
# 5      RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97   1707+
# 24  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437+
# 25  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437+
# 52       V Kohli (IND)  2011-2024  113   191  11   8848  254*  49.15   15924
# 53       V Kohli (IND)  2011-2024  113   191  11   8848  254*  49.15   15924
#
#        SR  100  50   0     4s  6s
# 3   54.48    7  11   1   246+  11
# 5   54.48    7  11   1   246+  11
# 24  54.04   51  68  14  2058+  69
# 25  54.04   51  68  14  2058+  69
# 52  55.56   29  30  14    991  26
# 53  55.56   29  30  14    991  26

# %% [markdown]
# **Drop the Duplicates**

# %%
df = df.drop_duplicates()

# %% [markdown]
# **Check the Duplicates are Droped or Not**

# %%
df[df['Player'].isin(['RG Pollock (SA)','SR Tendulkar (IND)','V Kohli (IND)'])]
# Out:
#                 Player       Span  Mat  Inns  NO   Runs    HS    Ave      BF  \
# 3      RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97   1707+
# 24  SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78  29437+
# 52       V Kohli (IND)  2011-2024  113   191  11   8848  254*  49.15   15924
#
#        SR  100  50   0     4s  6s
# 3   54.48    7  11   1   246+  11
# 24  54.04   51  68  14  2058+  69
# 52  55.56   29  30  14    991  26

# %% [markdown]
# **Split up Span into Debut and Retired**

# %%
df['Debut'] = df['Span'].str.split(pat='-').str[0]
df['Retired'] = df['Span'].str.split(pat='-').str[1]
df.head(1)
# Out:
#              Player       Span  Mat  Inns  NO  Runs   HS    Ave     BF    SR  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996  334  99.94  9800+  58.6
#
#    100  50  0    4s 6s Debut Retired
# 0   29  13  7  626+  6  1928    1948

# %% [markdown]
# **Drop the Span**

# %%
df = df.drop(['Span'],axis = 1)
df.head()
# Out:
#              Player  Mat  Inns  NO  Runs    HS    Ave     BF     SR  100  50  \
# 0  DG Bradman (AUS)   52    80  10  6996   334  99.94  9800+  58.60   29  13
# 1    HC Brook (ENG)   12    20   1  1181   186  62.15   1287  91.76    4   7
# 2    AC Voges (AUS)   20    31   7  1485  269*  61.87   2667  55.68    5   4
# 3   RG Pollock (SA)   23    41   4  2256   274  60.97  1707+  54.48    7  11
# 4   GA Headley (WI)   22    40   4  2190  270*  60.83   416+  56.00   10   5
#
#    0    4s  6s Debut Retired
# 0  7  626+   6  1928    1948
# 1  1   141  23  2022    2023
# 2  2   186   5  2015    2016
# 3  1  246+  11  1963    1970
# 4  2  104+   1  1930    1954

# %% [markdown]
# **Split up into Player and Country**

# %%
df['Country'] = df['Player'].str.split(pat = '(' ).str[1]
df['Country'] = df['Country'].str.split(pat = ')').str[0]
df.head(2)
# Out:
#              Player  Mat  Inns  NO  Runs   HS    Ave     BF     SR  100  50  \
# 0  DG Bradman (AUS)   52    80  10  6996  334  99.94  9800+  58.60   29  13
# 1    HC Brook (ENG)   12    20   1  1181  186  62.15   1287  91.76    4   7
#
#    0    4s  6s Debut Retired Country
# 0  7  626+   6  1928    1948     AUS
# 1  1   141  23  2022    2023     ENG

# %% [markdown]
# **Split up into HS ,BF , 4s and 6s**

# %%
df['HS'] = df['HS'].str.split(pat = '*' ).str[0]
df['BF'] = df['BF'].str.split(pat = '+' ).str[0]
df['4s'] = df['4s'].str.split(pat = '+' ).str[0]
df['6s'] = df['6s'].str.split(pat = '+' ).str[0]
df.head()
# Out:
#              Player  Mat  Inns  NO  Runs   HS    Ave    BF     SR  100  50  0  \
# 0  DG Bradman (AUS)   52    80  10  6996  334  99.94  9800  58.60   29  13  7
# 1    HC Brook (ENG)   12    20   1  1181  186  62.15  1287  91.76    4   7  1
# 2    AC Voges (AUS)   20    31   7  1485  269  61.87  2667  55.68    5   4  2
# 3   RG Pollock (SA)   23    41   4  2256  274  60.97  1707  54.48    7  11  1
# 4   GA Headley (WI)   22    40   4  2190  270  60.83   416  56.00   10   5  2
#
#     4s  6s Debut Retired Country
# 0  626   6  1928    1948     AUS
# 1  141  23  2022    2023     ENG
# 2  186   5  2015    2016     AUS
# 3  246  11  1963    1970      SA
# 4  104   1  1930    1954      WI

# %% [markdown]
# **Check the Data type of Dataframe**

# %%
df.dtypes
# Out:
# Player      object
# Mat          int64
# Inns         int64
# NO           int64
# Runs         int64
# HS          object
# Ave        float64
# BF          object
# SR         float64
# 100          int64
# 50           int64
# 0            int64
# 4s          object
# 6s          object
# Debut       object
# Retired     object
# Country     object
# dtype: object

# %% [markdown]
# **Replace 'NaN' and '-' with 0**

# %%
df = df.replace('-',0)
df = df.replace('NaN',0)

# %% [markdown]
# **Type Casting**

# %%
df = df.astype({'Player':'str','HS':'int','BF':'int','4s':'int','6s':'int','Debut':'int','Retired':'int'})

# %% [markdown]
# **Change the Column Name**

# %%
df = df.rename(columns={'Mat':'Matchs','NO':'Not_Outs','HS':'High_Score','BF':'Ball_Faced','SR':'Strike_Rate'})
df.head(5)
# Out:
#              Player  Matchs  Inns  Not_Out  Runs  High_Score    Ave  \
# 0  DG Bradman (AUS)      52    80       10  6996         334  99.94
# 1    HC Brook (ENG)      12    20        1  1181         186  62.15
# 2    AC Voges (AUS)      20    31        7  1485         269  61.87
# 3   RG Pollock (SA)      23    41        4  2256         274  60.97
# 4   GA Headley (WI)      22    40        4  2190         270  60.83
#
#    Ball_Faced  Strike_Rate  100  50  0   4s  6s  Debut  Retired Country
# 0        9800        58.60   29  13  7  626   6   1928     1948     AUS
# 1        1287        91.76    4   7  1  141  23   2022     2023     ENG
# 2        2667        55.68    5   4  2  186   5   2015     2016     AUS
# 3        1707        54.48    7  11  1  246  11   1963     1970      SA
# 4         416        56.00   10   5  2  104   1   1930     1954      WI

# %% [markdown]
# **Calculation with Dataframe**

# %% [markdown]
# **Add collumn to Find the Career Length of each player**

# %%
df['Career_Length'] = df['Retired'] - df['Debut']
df.head(3)
# Out:
#              Player  Matchs  Inns  Not_Out  Runs  High_Score    Ave  \
# 0  DG Bradman (AUS)      52    80       10  6996         334  99.94
# 1    HC Brook (ENG)      12    20        1  1181         186  62.15
# 2    AC Voges (AUS)      20    31        7  1485         269  61.87
#
#    Ball_Faced  Strike_Rate  100  50  0   4s  6s  Debut  Retired Country  \
# 0        9800        58.60   29  13  7  626   6   1928     1948     AUS
# 1        1287        91.76    4   7  1  141  23   2022     2023     ENG
# 2        2667        55.68    5   4  2  186   5   2015     2016     AUS
#
#    Career_Length
# 0             20
# 1              1
# 2              1

# %% [markdown]
# **Find the Mean value of Career Length of all Players**

# %%
df['Career_Length'].mean()
# Out:
# 13.193548387096774

# %% [markdown]
# **Find the Strike Rate of Players who Played more then 10 years
# and also its Average**

# %%
df[df['Career_Length']>10]['Strike_Rate']
# Out:
# 0     58.60
# 4     56.00
# 6     34.59
# 8     42.42
# 10    38.07
# 11    53.58
# 12    54.19
# 13    53.50
# 14    46.22
# 15     0.00
# 16    39.34
# 17    45.97
# 19    51.41
# 22    51.53
# 23    63.88
# 24    54.04
# 26    60.51
# 27    45.99
# 28    42.51
# 29    52.39
# 30    52.12
# 31    58.72
# 35    43.31
# 36    43.35
# 37    48.64
# 38    60.10
# 39    54.51
# 40    41.09
# 42    69.77
# 43    38.81
# 44    51.45
# 45    56.52
# 46    54.02
# 48    40.16
# 49    30.04
# 50    82.23
# 52    55.56
# 54    55.92
# 56    29.11
# 57     0.00
# 58    46.92
# 59    43.74
# 60    49.16
# 61    59.67
# Name: Strike_Rate, dtype: float64

# %%
df[df['Career_Length']>10]['Strike_Rate']
# Out:
# 0      True
# 4      True
# 6     False
# 8     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16    False
# 17     True
# 19     True
# 22     True
# 23     True
# 24     True
# 26     True
# 27     True
# 28    False
# 29     True
# 30     True
# 31     True
# 35    False
# 36    False
# 37     True
# 38     True
# 39     True
# 40    False
# 42     True
# 43    False
# 44     True
# 45     True
# 46     True
# 48    False
# 49    False
# 50     True
# 52     True
# 54     True
# 56    False
# 57    False
# 58     True
# 59    False
# 60     True
# 61     True
# Name: Strike_Rate, dtype: bool

# %%
df[df['Career_Length']>10]['Strike_Rate'].mean()
# Out:
# 47.94681818181819
