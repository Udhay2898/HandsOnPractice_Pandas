# %% [markdown]
# <a href="https://colab.research.google.com/github/Udhay2898/Pandas_Tutorial_Code/blob/master/Groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Sets/tamilnadu_accidents.csv')
df.head()
# Out:
#          Date         Location Type of Vehicle Cause of Accident  \
# 0  01-01-2020            Salem             Bus     Drunk Driving
# 1  02-01-2020          Chennai           Truck       Bad Weather
# 2  03-01-2020  Tiruchirappalli             Bus   Road Conditions
# 3  04-01-2020  Tiruchirappalli       Motorbike       Bad Weather
# 4  05-01-2020  Tiruchirappalli             Bus       Bad Weather
#
#    Number of Injuries  Number of Deaths
# 0                   4                 1
# 1                   2                 4
# 2                   4                 3
# 3                   6                 3
# 4                   3                 3

# %%
g = df.groupby('Location')
g

# %%
for location,location_df in g:
  print(location)
  print(location_df)
# Out:
# Chennai
#           Date Location Type of Vehicle   Cause of Accident  \
# 1   02-01-2020  Chennai           Truck         Bad Weather
# 9   10-01-2020  Chennai           Truck  Distracted Driving
# 10  11-01-2020  Chennai   Auto Rickshaw  Distracted Driving
# 14  15-01-2020  Chennai       Motorbike  Distracted Driving
# 17  18-01-2020  Chennai   Auto Rickshaw     Road Conditions
# 21  22-01-2020  Chennai           Truck       Drunk Driving
# 23  24-01-2020  Chennai           Truck     Road Conditions
# 26  27-01-2020  Chennai             Car  Distracted Driving
# 31  01-02-2020  Chennai   Auto Rickshaw       Over Speeding
# 35  05-02-2020  Chennai           Truck       Over Speeding
# 43  13-02-2020  Chennai             Bus  Distracted Driving
# 44  14-02-2020  Chennai             Bus       Drunk Driving
# 46  16-02-2020  Chennai   Auto Rickshaw  Distracted Driving
# 53  23-02-2020  Chennai   Auto Rickshaw         Bad Weather
# ...

# %%
l = df['Location'].unique()
l
for i in l:
  print(i)
  print(g.get_group(i))
# Out:
# Salem
#           Date Location Type of Vehicle   Cause of Accident  \
# 0   01-01-2020    Salem             Bus       Drunk Driving
# 8   09-01-2020    Salem             Bus         Bad Weather
# 11  12-01-2020    Salem       Motorbike     Road Conditions
# 19  20-01-2020    Salem           Truck  Distracted Driving
# 37  07-02-2020    Salem           Truck     Road Conditions
# 41  11-02-2020    Salem           Truck     Road Conditions
# 45  15-02-2020    Salem             Car       Drunk Driving
# 47  17-02-2020    Salem           Truck       Drunk Driving
# 49  19-02-2020    Salem             Car  Distracted Driving
# 64  05-03-2020    Salem       Motorbike  Distracted Driving
# 67  08-03-2020    Salem   Auto Rickshaw       Drunk Driving
# 69  10-03-2020    Salem           Truck         Bad Weather
# 70  11-03-2020    Salem       Motorbike       Drunk Driving
# 71  12-03-2020    Salem             Car       Drunk Driving
# ...

# %%
g.describe()
# Out:
#                 Number of Injuries                                            \
#                              count      mean       std  min   25%  50%   75%
# Location
# Chennai                       22.0  4.318182  3.314993  0.0  1.25  4.0  7.75
# Coimbatore                    20.0  4.250000  3.176807  0.0  1.75  3.0  7.25
# Madurai                       17.0  4.705882  2.931823  0.0  4.00  4.0  7.00
# Salem                         19.0  5.263158  2.305600  1.0  4.00  6.0  7.00
# Tiruchirappalli               22.0  4.727273  2.353960  0.0  3.00  5.0  7.00
#
#                      Number of Deaths                                      \
#                  max            count      mean       std  min   25%  50%
# Location
# Chennai          9.0             22.0  2.363636  1.398824  0.0  1.25  2.5
# Coimbatore       9.0             20.0  2.200000  1.576138  0.0  1.00  2.5
# Madurai          9.0             17.0  1.705882  1.159995  0.0  1.00  2.0
# ...

# %%
# Out:
# Using matplotlib backend: <object object at 0x7d6384fd7ac0>
# Location
# Chennai            Axes(0.125,0.11;0.775x0.77)
# Coimbatore         Axes(0.125,0.11;0.775x0.77)
# Madurai            Axes(0.125,0.11;0.775x0.77)
# Salem              Axes(0.125,0.11;0.775x0.77)
# Tiruchirappalli    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
df.head(2)
# Out:
#          Date Location Type of Vehicle Cause of Accident  Number of Injuries  \
# 0  01-01-2020    Salem             Bus     Drunk Driving                   4
# 1  02-01-2020  Chennai           Truck       Bad Weather                   2
#
#    Number of Deaths
# 0                 1
# 1                 4

# %%
g = df.groupby('Type of Vehicle').count()

# %%
g.plot(figsize = (8,4))
# Out:
# <Axes: xlabel='Type of Vehicle'>
